# %%
import pandas as pd
import os

# %%
data = pd.read_csv("testwin.csv")

# %%
data
# Out:
#       EVENT_ID                 MENU_HINT       EVENT_NAME          EVENT_DT  \
# 0    170267515  AUS / Gund (AUS) 5th Apr    R5 1400m Hcap  05-04-2020 05:55
# 1    170267515  AUS / Gund (AUS) 5th Apr    R5 1400m Hcap  05-04-2020 05:55
# 2    170267507  AUS / Gund (AUS) 5th Apr     R1 1180m Mdn  05-04-2020 03:30
# 3    170267521  AUS / Gund (AUS) 5th Apr    R8 1180m Hcap  05-04-2020 07:55
# 4    170267521  AUS / Gund (AUS) 5th Apr    R8 1180m Hcap  05-04-2020 07:55
# 5    170267521  AUS / Gund (AUS) 5th Apr    R8 1180m Hcap  05-04-2020 07:55
# 6    170267521  AUS / Gund (AUS) 5th Apr    R8 1180m Hcap  05-04-2020 07:55
# 7    170267511  AUS / Gund (AUS) 5th Apr     R3 1800m CL1  05-04-2020 04:45
# 8    170267511  AUS / Gund (AUS) 5th Apr     R3 1800m CL1  05-04-2020 04:45
# 9    170267511  AUS / Gund (AUS) 5th Apr     R3 1800m CL1  05-04-2020 04:45
# 10   170267519  AUS / Gund (AUS) 5th Apr    R7 1800m Hcap  05-04-2020 07:15
# ...

# %%
grouped = data.groupby(["EVENT_ID"])

# %%
for name, group in grouped:
    print(name, group)
# Out:
# 170267507       EVENT_ID                 MENU_HINT    EVENT_NAME          EVENT_DT  \
# 2    170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 111  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 112  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 299  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 300  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 301  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 485  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 684  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
# 685  170267507  AUS / Gund (AUS) 5th Apr  R1 1180m Mdn  05-04-2020 03:30
#
#      SELECTION_ID          SELECTION_NAME  WIN_LOSE         BSP       PPWAP  \
# 2        28286542        3. Certain Shaft         0    3.900000    3.106517
# ...
