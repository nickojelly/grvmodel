# %%
import os
import pandas as pd

# %%
df = pd.read_json(r"C:\Users\Nick\Documents\GitHub\grvmodel\Python\pytorch\New Model\wandb\run-20220701_230752-8oteul8s\files\media\table\table_key_552415_eb954d01e5c2993c54a0.table.json", orient = 'split')

# %%
df
# Out:
#       class  pred       max  correct  priceR  priceP  bets  \
# 0         0     3  0.190517        0     1.7     3.7     2
# 1         0     4  0.157416        0     4.2     3.7     2
# 2         6     6  0.155012        1     3.9     3.9     2
# 3         4     1  0.145543        0     5.6    11.1     2
# 4         3     5  0.175398        0    10.7     2.7     2
# ...     ...   ...       ...      ...     ...     ...   ...
# 9995      7     7  0.150260        1     2.6     2.6     2
# 9996      7     5  0.189459        0     3.0     2.1     2
# 9997      6     7  0.154834        0     3.7     3.5     2
# 9998      6     5  0.150036        0     5.9     5.9     2
# 9999      3     1  0.248655        0     6.3     3.6     2
#
#                                               pred_odds  \
# 0     [6.072661949952779, 6.213734390307181, 5.83419...
# 1     [8.262115313142033, 8.098025331312906, 7.41764...
# 2     [9.54949714323335, 8.289734563017623, 7.735589...
# ...
