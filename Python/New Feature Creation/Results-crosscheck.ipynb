# %%
#Imports
import os
import xml.etree.ElementTree as ET
import pandas as pd
from datetime import datetime
import pickle
import tqdm
import line_profiler
from operator import itemgetter
from sklearn.preprocessing import OneHotEncoder
import math
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
os.getcwd()
os.chdir(r"C:\Users\Nick\Documents\GitHub\grvmodel\Python\DATA")
resultspicklefile = open( 'results-df.npy', 'rb')
resultsdf = pickle.load(resultspicklefile)
resultsdf = pd.DataFrame(resultsdf)

# %%
resultsdf[resultsdf['race_id']=="140918784"].sort_values('box')
# Out:
#          race_id       date    track  dist                grade  place  \
# 59839  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    3.0
# 59838  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    2.0
# 59843  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    7.0
# 59840  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    4.0
# 59837  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    1.0
# 59842  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    6.0
# 59841  140918784  05 Aug 16  Bendigo  425m  Restricted Win Heat    5.0
#
#            dog_id box split_times split_margins run_time weigth margin  \
# 59839   940060041   1        6.66          0.05    24.41   31.0   1.86
# 59838   641490415   3        6.63          0.02    24.34   32.4   0.81
# 59843   687310007   4        6.70          0.09    25.46   28.4  16.73
# 59840   931140044   5        6.72          0.11    24.98   25.0   9.93
# 59837  1249530005   6        6.61          0.00    24.28   27.4      0
# 59842   879520040   7        6.79          0.18    25.19   28.7  12.96
# 59841   275790103   8        6.82          0.21    25.13   29.5  12.11
#
#        start_price          dog_name
# 59839          3.5            MARODO
# 59838         10.2        MORTAL SIN
# 59843          9.7      SUNDANCE LAD
# 59840         20.8    RIVERSIDE MONS
# 59837          7.3          MISS PIE
# 59842         26.7   TALTARNI SHIRAZ
# 59841         25.9  THUNDEROUS NIGHT

# %%
resultsdf.shape
# Out:
# (537871, 15)
