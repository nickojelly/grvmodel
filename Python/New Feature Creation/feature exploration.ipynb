# %%
#Imports
import os
import pandas as pd
from datetime import datetime
import pickle

# %%
resultspicklefile = open("input_list.npy", 'rb')
inputFile = pickle.load(resultspicklefile)
inputDf = pd.DataFrame(inputFile)

# %%
inputDf.head(20)
# Out:
#     0         1         2         3         4         5         6    \
# 0     1  0.059672  0.001304  0.061486  0.058902  0.000953  0.059994
# 1     1  0.057393  0.000713  0.057897  0.058254  0.001901  0.059598
# 2     5       NaN       NaN       NaN       NaN       NaN       NaN
# 3     4       NaN       NaN       NaN       NaN       NaN       NaN
# 4     2       NaN       NaN       NaN       NaN       NaN       NaN
# 5     8       NaN       NaN       NaN       NaN       NaN       NaN
# 6     6       NaN       NaN       NaN       NaN       NaN       NaN
# 7     2  0.058409  0.000555  0.059223  0.057947  0.001001  0.059986
# 8     8  0.058489  0.000733  0.059697  0.058365  0.002040  0.061390
# 9     1  0.058364  0.001812  0.061010  0.057142  0.000683  0.058080
# 10    5  0.057370  0.000486  0.058261  0.057054  0.001366  0.059684
# 11    5  0.057779  0.000662  0.058400  0.057378  0.000447  0.057981
# 12    4  0.055867       NaN  0.055867  0.054811       NaN  0.054811
# ...
