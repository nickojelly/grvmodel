# %% [markdown]
# Full pandas dataframe created for all shep race results
#
# todo:
# create graph of box number vs place
# create lin model of distance box vs time/place?
#
# idea:
# clustering analysis of dog to predict dogs that will behave the same

# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

# %%
file_list = os.listdir()
path = os.getcwd()

master_list = result_getter(file_list, path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-511f87a93495> in <module>
#       2 path = os.getcwd()
#       3
# ----> 4 master_list = result_getter(file_list, path)
#
# <ipython-input-3-68b5db64ba67> in result_getter(file_list, path)
#       3
#       4     for i in file_list:
# ----> 5         root = ET.parse(i).getroot()
#       6
#       7         track = root[0]
#
# C:\ProgramData\Anaconda3\lib\xml\etree\ElementTree.py in parse(source, parser)
#    1195     """
#    1196     tree = ElementTree()
# -> 1197     tree.parse(source, parser)
#    1198     return tree
#    1199
#
# C:\ProgramData\Anaconda3\lib\xml\etree\ElementTree.py in parse(self, source, parser)
#     585         close_source = False
#     586         if not hasattr(source, "read"):
# --> 587             source = open(source, "rb")
#     588             close_source = True
#     589         try:
#
# PermissionError: [Errno 13] Permission denied: '.ipynb_checkpoints'

# %%
def result_getter(file_list, path):
    master_list = []
    
    for i in file_list:
        root = ET.parse(i).getroot()

        track = root[0]
        print("track =", track.text)
        date = root[1]
        print("date =", date.text)


        for race in root.iter('Race'):
            print("race number = ",race[0].text)
            print("Distance =", race[3].text, "\n")
            print("place name box split split_margin runtime")

            places = []
            ids = []
            boxes = []
            splittimes = []
            split_margin =[]
            runtimes = []

            for dog in race.iter('Dog'):
                if not dog.attrib["id"]:
                    continue
                if (dog[0].text == "R")or(dog[0].text == "S"):
                    #print("scratched check working")
                    continue
                places.append(dog[0].text)
                ids.append(dog.attrib["id"])
                boxes.append(dog[3].text)
                splittimes.append(dog[13].text)
                runtimes.append(dog[14].text)

            for i in range(len(splittimes)):
                if splittimes[0] == None:
                    split_margin.append("N/A")
                    continue
                try:
                    split_margin.append(float(splittimes[i])-float(splittimes[0]))
                except:
                    split_margin.append("N/A")

            for i in range(len(places)):
                try:
                    print(places[i], ids[i], boxes[i], splittimes[i], "%.2f" % split_margin[i], runtimes[i])
                except :
                    print(places[i], ids[i], boxes[i], splittimes[i], split_margin[i], runtimes[i])

            print("\n------------------------\n")
            zipall = list(zip(places,ids,boxes,splittimes,split_margin,runtimes))
            print(zipall)
            for i in range(len(zipall)):
                zipall[i] = (race.attrib["id"], race[3].text,) + zipall[i]
                master_list.append(zipall[i])

    return master_list

# %%
col_names = ["race_id", "dist", "place", "dog_id", "box", "split_times", "split_margins", "run_time"]
df = pd.DataFrame(master_list, columns = col_names)
df
# Out:
#          race_id  dist place      dog_id box split_times split_margins  \
# 0      422654631  450m     1   250185388   6        6.79             0
# 1      422654631  450m     2   256198377   3        7.01          0.22
# 2      422654631  450m     3   251075794   1        7.02          0.23
# 3      422654631  450m     4   219044248   2        6.87          0.08
# 4      422654631  450m     5   231578733   7        6.94          0.15
# 5      422654631  450m     6   251383268   4        6.75         -0.04
# 6      422654625  390m     1   179536445   6        8.88             0
# 7      422654625  390m     2   250185389   1        8.74         -0.14
# 8      422654625  390m     3   109494053   3        8.74         -0.14
# 9      422654625  390m     4   222735081   2        8.78          -0.1
# 10     422654625  390m     5   250185384   7        8.79         -0.09
# 11     422654625  390m     6   138443840   5        8.74         -0.14
# 12     422654625  390m     7   254393783   4        8.73         -0.15
# 13     422654626  390m     1   256198375   1        8.66             0
# 14     422654626  390m     2   163734337   2        8.69          0.03
# 15     422654626  390m     3  1608070005   6        8.48         -0.18
# 16     422654626  390m     4   264508971   8        8.73          0.07
# 17     422654626  390m     5   230317216   3        8.76           0.1
# 18     422654626  390m     6   251075249   4        8.78          0.12
# 19     422654626  390m     7   208771209   5        8.96           0.3
# 20     422654626  390m     8   189163586   7        8.77          0.11
# 21     422654627  390m     1   251076280   3        8.74             0
# 22     422654627  390m     2   253386766   2        8.61         -0.13
# 23     422654627  390m     3   172047915   6        8.66         -0.08
# 24     422654627  390m     4   118782594   8        8.81          0.07
# 25     422654627  390m     5   141319087   5        8.89          0.15
# 26     422654627  390m     6   120321675   1        8.67         -0.07
# 27     422654627  390m     7   163764378   7        8.81          0.07
# 28     422654627  390m     8   129971929   4        8.88          0.14
# 29     422654633  450m     1   212745829   4        6.63             0
# ...          ...   ...   ...         ...  ..         ...           ...
# 24046  490421895  450m     5   111277152   2        7.21           0.3
# 24047  490421888  390m     1  2099800062   4        8.48             0
# 24048  490421888  390m     2   198170064   2        8.78           0.3
# 24049  490421888  390m     3   214449062   6        8.83          0.35
# 24050  490421888  390m     4   159733334   1        8.66          0.18
# 24051  490421888  390m     5  1340420023   3        9.02          0.54
# 24052  490421888  390m     6   208823814   7        8.88           0.4
# 24053  490421888  390m     T  1881150215   8        9.16          0.68
# 24054  490421891  390m     1   287325522   4        8.72             0
# 24055  490421891  390m     2  2138930022   7        8.53         -0.19
# 24056  490421891  390m     3   262316117   5        8.76          0.04
# 24057  490421891  390m     4   120321675   2        8.90          0.18
# 24058  490421891  390m     5   248770554   1        8.92           0.2
# 24059  490421891  390m     6   148672770   8        9.13          0.41
# 24060  490421889  390m     1   129971928   1        8.63             0
# 24061  490421889  390m     2   114244038   2        8.59         -0.04
# 24062  490421889  390m     3  1745540008   3        8.82          0.19
# 24063  490421889  390m     4  1590360002   7        8.91          0.28
# 24064  490421889  390m     5   113531648   6        8.96          0.33
# 24065  490421890  390m     1   137471395   1        8.75             0
# 24066  490421890  390m     2  1389280131   4        8.54         -0.21
# 24067  490421890  390m     3  1182160100   8        8.86          0.11
# 24068  490421890  390m     4  1284200017   7        8.93          0.18
# 24069  490421890  390m     5   111276625   6        9.14          0.39
# 24070  490421890  390m     6   111276685   2        9.21          0.46
# 24071  490421886  390m     1  1328610013   2        8.44             0
# 24072  490421886  390m     2   224869342   1        8.58          0.14
# 24073  490421886  390m     3   184223212   7        8.66          0.22
# 24074  490421886  390m     4   296096032   8        8.65          0.21
# 24075  490421886  390m     5   124885844   4        8.66          0.22
#
#       run_time
# 0        26.00
# 1        26.06
# 2        26.26
# 3        26.49
# 4        27.09
# 5        28.13
# 6        23.19
# 7        23.22
# 8        23.23
# 9        23.26
# 10       23.31
# 11       23.54
# 12       23.54
# 13       22.50
# 14       22.53
# 15       22.55
# 16       22.61
# 17       22.73
# 18       23.09
# 19       23.15
# 20       23.19
# 21       22.46
# 22       22.55
# 23       22.64
# 24       22.75
# 25       22.89
# 26       22.92
# 27       22.94
# 28       23.05
# 29       25.20
# ...        ...
# 24046    26.18
# 24047    22.45
# 24048    22.67
# 24049    22.70
# 24050    22.71
# 24051    22.82
# 24052    22.83
# 24053     None
# 24054    22.38
# 24055    22.42
# 24056    22.51
# 24057    22.94
# 24058    22.99
# 24059    23.48
# 24060    22.67
# 24061    22.68
# 24062    22.85
# 24063    22.99
# 24064    23.11
# 24065    22.65
# 24066    22.72
# 24067    22.76
# 24068    22.76
# 24069    22.76
# 24070    23.46
# 24071    22.31
# 24072    22.53
# 24073    22.74
# 24074    22.75
# 24075    22.83
#
# [24076 rows x 8 columns]

# %%
#full pandas

# %%
os.chdir(r'C:\Users\Nick\OneDrive - The University of Melbourne\personal projects\greyhound model\greyhound data\results')

# %%
file_list = os.listdir()
path = os.getcwd()
print(file_list)
# Out:
# ['rr-SHP01Apr19.xml', 'rr-SHP01Apr20.xml', 'rr-SHP01Aug16.xml', 'rr-SHP01Aug19.xml', 'rr-SHP01Dec16.xml', 'rr-SHP01Jul19.xml', 'rr-SHP01Nov18.xml', 'rr-SHP01Oct18.xml', 'rr-SHP01Sep16.xml', 'rr-SHP02Apr18.xml', 'rr-SHP02Aug18.xml', 'rr-SHP02Dec19.xml', 'rr-SHP02Jan17.xml', 'rr-SHP02Jul18.xml', 'rr-SHP02Mar20.xml', 'rr-SHP02May19.xml', 'rr-SHP02Nov19.xml', 'rr-SHP02Sep19.xml', 'rr-SHP03Dec16.xml', 'rr-SHP03Dec18.xml', 'rr-SHP03Feb20.xml', 'rr-SHP03Jan19.xml', 'rr-SHP03Jan20.xml', 'rr-SHP03Jun19.xml', 'rr-SHP03May18.xml', 'rr-SHP03Nov18.xml', 'rr-SHP03Oct16.xml', 'rr-SHP03Oct19.xml', 'rr-SHP03Sep18.xml', 'rr-SHP04Apr19.xml', 'rr-SHP04Aug16.xml', 'rr-SHP04Aug18.xml', 'rr-SHP04Feb19.xml', 'rr-SHP04Jul19.xml', 'rr-SHP04Jun18.xml', 'rr-SHP04Mar19.xml', 'rr-SHP04May20.xml', 'rr-SHP05Apr18.xml', 'rr-SHP05Aug19.xml', 'rr-SHP05Dec16.xml', 'rr-SHP05Feb20.xml', 'rr-SHP05Jul18.xml', 'rr-SHP05Mar20.xml', 'rr-SHP05Sep16.xml', 'rr-SHP05Sep19.xml', 'rr-SHP06Apr20.xml', 'rr-SHP06Aug18.xml', 'rr-SHP06Dec18.xml', 'rr-SHP06Dec19.xml', 'rr-SHP06Jan17.xml', 'rr-SHP06Jan20.xml', 'rr-SHP06Jul19.xml', 'rr-SHP06Jun19.xml', 'rr-SHP06May19.xml', 'rr-SHP06Oct16.xml', 'rr-SHP06Oct18.xml', 'rr-SHP06Sep18.xml', 'rr-SHP07Feb19.xml', 'rr-SHP07Jan19.xml', 'rr-SHP07Jul16.xml', 'rr-SHP07Jun18.xml', 'rr-SHP07Mar20.xml', 'rr-SHP07May18.xml', 'rr-SHP07Nov19.xml', 'rr-SHP07Oct19.xml', 'rr-SHP07Sep19.xml', 'rr-SHP08Apr19.xml', 'rr-SHP08Aug16.xml', 'rr-SHP08Aug19.xml', 'rr-SHP08Dec16.xml', 'rr-SHP08Jul19.xml', 'rr-SHP08Nov18.xml', 'rr-SHP08Sep16.xml', 'rr-SHP08Sep18.xml', 'rr-SHP09Apr18.xml', 'rr-SHP09Aug18.xml', 'rr-SHP09Dec19.xml', 'rr-SHP09Jan17.xml', 'rr-SHP09Jan20.xml', 'rr-SHP09Jul18.xml', 'rr-SHP09Mar19.xml', 'rr-SHP09Mar20.xml', 'rr-SHP09May19.xml', 'rr-SHP09Sep19.xml', 'rr-SHP10Dec18.xml', 'rr-SHP10Feb20.xml', 'rr-SHP10Jan19.xml', 'rr-SHP10Jun19.xml', 'rr-SHP10May18.xml', 'rr-SHP10Oct16.xml', 'rr-SHP10Oct19.xml', 'rr-SHP10Sep18.xml', 'rr-SHP11Apr19.xml', 'rr-SHP11Aug16.xml', 'rr-SHP11Feb19.xml', 'rr-SHP11Jul16.xml', 'rr-SHP11Jul19.xml', 'rr-SHP11Jun18.xml', 'rr-SHP11Mar19.xml', 'rr-SHP11Nov19.xml', 'rr-SHP12Apr18.xml', 'rr-SHP12Aug19.xml', 'rr-SHP12Dec19.xml', 'rr-SHP12Jan17.xml', 'rr-SHP12Jul18.xml', 'rr-SHP12Mar20.xml', 'rr-SHP12Nov18.xml', 'rr-SHP12Oct19.xml', 'rr-SHP12Sep16.xml', 'rr-SHP12Sep19.xml', 'rr-SHP13Apr20.xml', 'rr-SHP13Aug18.xml', 'rr-SHP13Dec18.xml', 'rr-SHP13Feb20.xml', 'rr-SHP13Jan20.xml', 'rr-SHP13Jun19.xml', 'rr-SHP13May19.xml', 'rr-SHP13Oct16.xml', 'rr-SHP13Sep18.xml', 'rr-SHP14Jul16.xml', 'rr-SHP14Jun18.xml', 'rr-SHP14Mar19.xml', 'rr-SHP14May18.xml', 'rr-SHP14Nov19.xml', 'rr-SHP14Oct19.xml', 'rr-SHP15Apr19.xml', 'rr-SHP15Aug16.xml', 'rr-SHP15Aug19.xml', 'rr-SHP15Feb20.xml', 'rr-SHP15Jul19.xml', 'rr-SHP15Nov18.xml', 'rr-SHP15Oct18.xml', 'rr-SHP15Sep16.xml', 'rr-SHP16Apr18.xml', 'rr-SHP16Apr20.xml', 'rr-SHP16Dec19.xml', 'rr-SHP16Jan17.xml', 'rr-SHP16Jan20.xml', 'rr-SHP16Jul18.xml', 'rr-SHP16Mar20.xml', 'rr-SHP16May19.xml', 'rr-SHP16Sep19.xml', 'rr-SHP17Dec18.xml', 'rr-SHP17Feb20.xml', 'rr-SHP17Jun19.xml', 'rr-SHP17Nov16.xml', 'rr-SHP17Oct16.xml', 'rr-SHP17Oct19.xml', 'rr-SHP17Sep16.xml', 'rr-SHP17Sep18.xml', 'rr-SHP18Apr20.xml', 'rr-SHP18Aug16.xml', 'rr-SHP18Aug18.xml', 'rr-SHP18Jul16.xml', 'rr-SHP18Jul19.xml', 'rr-SHP18Jun18.xml', 'rr-SHP18Mar19.xml', 'rr-SHP18Mar20.xml', 'rr-SHP18Nov19.xml', 'rr-SHP18Oct18.xml', 'rr-SHP19Apr18.xml', 'rr-SHP19Aug19.xml', 'rr-SHP19Dec19.xml', 'rr-SHP19Jan17.xml', 'rr-SHP19Jan19.xml', 'rr-SHP19Jul18.xml', 'rr-SHP19May18.xml', 'rr-SHP19Nov18.xml', 'rr-SHP19Sep16.xml', 'rr-SHP19Sep19.xml', 'rr-SHP20Apr20.xml', 'rr-SHP20Aug18.xml', 'rr-SHP20Feb20.xml', 'rr-SHP20Jan19.xml', 'rr-SHP20Jan20.xml', 'rr-SHP20May19.xml', 'rr-SHP20Oct16.xml', 'rr-SHP20Sep18.xml', 'rr-SHP21Aug19.xml', 'rr-SHP21Dec19.xml', 'rr-SHP21Jul16.xml', 'rr-SHP21Jun18.xml', 'rr-SHP21Mar19.xml', 'rr-SHP21Mar20.xml', 'rr-SHP21May18.xml', 'rr-SHP21Nov16.xml', 'rr-SHP21Oct19.xml', 'rr-SHP22Apr19.xml', 'rr-SHP22Aug16.xml', 'rr-SHP22Aug19.xml', 'rr-SHP22 ...
